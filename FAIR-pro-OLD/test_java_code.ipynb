# %%
import numpy as np
import pandas as pd
import scipy as sp
from scipy.ndimage.filters import gaussian_filter as smooth

# %matplotlib inline
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = 16, 9
plt.rcParams['lines.linewidth'] = 3

font = {'weight' : 'normal',
      'size'   : 17}

plt.rc('font', **font)

temperature_file = './test_java_fair.txt'
temperature_data = np.genfromtxt(temperature_file,skip_header=0,delimiter='\n',names=True)

# %%
from forward_original import fair_scm as fair

emissions = np.zeros(266)
emissions[100] = 100.0

C,T,RF = fair(emissions = emissions)
plt.plot(np.arange(266), T, color = 'red')
plt.plot(np.arange(266), temperature_data, color = 'blue')
